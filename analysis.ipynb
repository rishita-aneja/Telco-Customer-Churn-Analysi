# %% [markdown]
# # Customer Churn Analysis Project

# %%
import pandas as pd

# Load dataset
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# Show first 5 rows
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# ## Problem Statement
#
# The objective of this project is to analyze customer data to identify key factors contributing to customer churn and provide actionable insights to improve customer retention.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   str
#  1   gender            7043 non-null   str
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   str
#  4   Dependents        7043 non-null   str
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   str
#  7   MultipleLines     7043 non-null   str
#  8   InternetService   7043 non-null   str
#  9   OnlineSecurity    7043 non-null   str
#  10  OnlineBackup      7043 non-null   str
#  11  DeviceProtection  7043 non-null   str
#  12  TechSupport       7043 non-null   str
#  13  StreamingTV       7043 non-null   str
#  14  StreamingMovies   7043 non-null   str
#  15  Contract          7043 non-null   str
#  16  PaperlessBilling  7043 non-null   str
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %% [markdown]
# ## Data Cleaning
#
# - Handled missing values
# - Converted TotalCharges to numeric
# - Ensured dataset consistency

# %%
import pandas as pd
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="Churn", data=df)
plt.show()

# %% [markdown]
# ### Insight:
# Majority of customers are retained, but a significant portion has churned.

# %%
sns.boxplot(x="Churn", y="MonthlyCharges", data=df)
plt.show()

# %% [markdown]
# ### Insight:
# Customers with higher monthly charges are more likely to churn.

# %%
sns.countplot(x="Contract", hue="Churn", data=df)
plt.show()

# %% [markdown]
# ### Insight:
# Month-to-month contract customers show higher churn compared to long-term contracts.

# %%
sns.boxplot(x="Churn", y="tenure", data=df)
plt.show()

# %% [markdown]
# ### Insight:
# Customers with lower tenure are more likely to churn, indicating new customers are at higher risk.

# %% [markdown]
# ## Final Insights
#
# High monthly charges, short-term contracts, and low tenure significantly increase churn risk. Long-term customers with stable contracts are more likely to stay.

# %% [markdown]
# ## Recommendations
#
# - Promote long-term contracts with discounts
# - Offer benefits to high-paying customers
# - Improve onboarding for new customers
# - Target at-risk customers with retention strategies

# %% [markdown]
# ## Conclusion
#
# This analysis identified key factors influencing churn and provided actionable insights to improve customer retention.
